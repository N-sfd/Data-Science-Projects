# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)

# %%
tokenization("This is my wording for Music Recommendation")
# Out:
# 'thi is my word for music recommend'

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a6903730c12f> in <cell line: 2>()
#       1 tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
# ----> 2 matrix = tfidvector.fit_transform(df['text'])
#       3 similarity = cosine_similarity(matrix)
#
# NameError: name 'df' is not defined

# %%
similarity
# Out:
# array([[1.        , 0.00483489, 0.00187024, ..., 0.0164056 , 0.01259205,
#         0.00386499],
#        [0.00483489, 1.        , 0.01029751, ..., 0.02918534, 0.02092571,
#         0.00754907],
#        [0.00187024, 0.01029751, 1.        , ..., 0.0295074 , 0.15052998,
#         0.00609038],
#        ...,
#        [0.0164056 , 0.02918534, 0.0295074 , ..., 1.        , 0.0253715 ,
#         0.03313027],
#        [0.01259205, 0.02092571, 0.15052998, ..., 0.0253715 , 1.        ,
#         0.01350971],
#        [0.00386499, 0.00754907, 0.00609038, ..., 0.03313027, 0.01350971,
#         1.        ]])

# %%
df['song'][2]
# Out:
# 'How Can It Hurt'

# %%
df[df['song'] == 'How Can It Hurt']
# Out:
#       artist             song  \
# 2  Marillion  How Can It Hurt
#
#                                                 text          Nobody's Fool  \
# 2  mayb you 're just too upset insid to give it t...  Silent In The Morning
#
#    Silent In The Morning        How Can It Hurt Something To Believe In  \
# 2  Silent In The Morning  Silent In The Morning   Silent In The Morning
#
#                Cry Tough     All Dead, All Dead                  Stars  ...  \
# 2  Silent In The Morning  Silent In The Morning  Silent In The Morning  ...
#
#        I Am Not American              I Like It       Marys Of The Sea  \
# 2  Silent In The Morning  Silent In The Morning  Silent In The Morning
#
#        Everywhere I Turn            Off He Goes  \
# 2  Silent In The Morning  Silent In The Morning
#
#   Got To Get Better In A Little While I Think It's Going To Rain Today  \
# 2               Silent In The Morning            Silent In The Morning
#
#                Play Dead          Doin The Most        Western Promise
# 2  Silent In The Morning  Silent In The Morning  Silent In The Morning
#
# [1 rows x 4768 columns]

# %%
def recommendation(song):
  idx = df[df['song'] == song].index[0]

# %%
sorted(list(enumerate(similarity[0])),reverse=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fdf5045f667e> in <cell line: 1>()
# ----> 1 sorted(list(enumerate(similarity[0])),reverse=False)
#
# NameError: name 'similarity' is not defined
